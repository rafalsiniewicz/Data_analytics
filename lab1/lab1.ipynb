# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# <h1><center>Import data</h1></center>

# %%
data = pd.read_csv("data1.txt", index_col=0)

# %% [markdown]
# <h1><center>Show data</h1></center>

# %%
data.head()
# Out:
#              theta_1   theta_2   theta_3   theta_4   theta_5   theta_6
# 2017-01-01  0.756936 -1.467790  0.096136 -0.115306 -0.447908  0.902579
# 2017-01-02  0.767089  0.185797 -1.428536 -0.086443 -0.954288  1.930909
# 2017-01-03  0.404544  1.415887  0.443466  0.000200 -0.892351  2.449691
# 2017-01-04  1.313957 -1.804471 -0.836986  0.011785 -1.012518  1.182085
# 2017-01-05  0.209862  1.315868  0.140993 -0.046473 -1.417092  1.742433

# %%
data["theta_1"].plot()

# %%
data["theta_2"].plot()

# %%
data["theta_3"].plot()

# %%
data["theta_4"].plot()

# %%
data["theta_5"].plot()

# %%
data["theta_6"].plot()

# %%
data.plot()

# %% [markdown]
# <h1><center>
#     Plot data histograms
# </h1></center>
# <center>For most thetas most values are equal 0. All values are from range -15 to 15.</center>

# %%
plt.style.use('seaborn')
data.plot.hist(legend=True)

# %% [markdown]
# <h1><center>Plot Kernel Density Estimation for data</h1></center>
# <center>Density functions show expected results, after seeing histograms. Most thetas have most probable values oscillating near 0. For most thetas the most probable value is 0</center>

# %%
data["theta_1"].plot.kde()

# %%
data["theta_2"].plot.kde()

# %%
data["theta_3"].plot.kde()

# %%
data["theta_4"].plot.kde()

# %%
data["theta_5"].plot.kde()

# %%
data["theta_6"].plot.kde()

# %% [markdown]
# <h1><center>Plot Kde's for all data</h1></center>

# %%
data.plot.kde()

# %% [markdown]
# <h1><center>Choose data with date between 2018-01-01 and 2018-12-31</h1></center>

# %%
data = data.loc['2018-01-01':'2018-12-31']

# %%
print(data)
# Out:
#              theta_1   theta_2   theta_3   theta_4   theta_5   theta_6
# 2018-01-01  0.682693 -3.091767 -0.475717 -0.238530  0.036404  4.551359
# 2018-01-02 -0.283107 -0.979955  1.233933  0.158031 -0.097014  4.623086
# 2018-01-03  1.572221 -2.033528  2.196317  0.041347  0.009982  4.330249
# 2018-01-04 -1.042981  0.651530  1.060125  0.064832  0.036592  6.617830
# 2018-01-05 -1.392614 -2.570905 -0.600063 -0.015025  0.124576  5.577570
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-27  0.473556 -0.651265 -0.523058  0.076798  0.026654  8.459625
# 2018-12-28  1.433117  0.325632  0.905920  0.028891  0.040696  9.396884
# 2018-12-29  0.285428 -0.476290  1.082404  0.111482  0.031700  7.285139
# 2018-12-30  2.249273 -1.233575 -0.666277 -0.080878  0.004340  7.776090
# 2018-12-31  0.316409  5.673544 -0.964592 -0.150844 -0.091405  6.495294
#
# [365 rows x 6 columns]

# %%
data = data[['theta_1','theta_2','theta_3','theta_4']]
print(data)
# Out:
#              theta_1   theta_2   theta_3   theta_4
# 2018-01-01  0.682693 -3.091767 -0.475717 -0.238530
# 2018-01-02 -0.283107 -0.979955  1.233933  0.158031
# 2018-01-03  1.572221 -2.033528  2.196317  0.041347
# 2018-01-04 -1.042981  0.651530  1.060125  0.064832
# 2018-01-05 -1.392614 -2.570905 -0.600063 -0.015025
# ...              ...       ...       ...       ...
# 2018-12-27  0.473556 -0.651265 -0.523058  0.076798
# 2018-12-28  1.433117  0.325632  0.905920  0.028891
# 2018-12-29  0.285428 -0.476290  1.082404  0.111482
# 2018-12-30  2.249273 -1.233575 -0.666277 -0.080878
# 2018-12-31  0.316409  5.673544 -0.964592 -0.150844
#
# [365 rows x 4 columns]

# %%
data["theta_1"].plot()

# %%
data["theta_2"].plot()

# %%
data["theta_3"].plot()

# %%
data["theta_4"].plot()

# %%
data.plot()

# %% [markdown]
# <h1><center>Plot histograms and kde's for selected data</h1></center>

# %%
plt.style.use('seaborn')
data.plot.hist(legend=True)

# %%
data["theta_1"].plot.kde()

# %%
data["theta_2"].plot.kde()

# %%
data["theta_3"].plot.kde()

# %%
data["theta_4"].plot.kde()

# %%
data.plot.kde()
